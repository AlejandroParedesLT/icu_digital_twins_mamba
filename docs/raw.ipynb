# %%
import polars as pl

df = pl.read_parquet('/home/ap794/wspersonal/icu_digital_twins_mamba/data/patient_sequences/patient_sequences_2048_labeled_fixed.parquet')
df.head()
# Out:
# shape: (5, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ subject_i ┆ event_tok ┆ type_toke ┆ age_token ┆ … ┆ rare_cond ┆ label_mor ┆ label_mor ┆ label_se │
# │ d         ┆ ens_2048  ┆ ns_2048   ┆ s_2048    ┆   ┆ itions    ┆ tality_2w ┆ tality_1m ┆ psis     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ eeks      ┆ onth      ┆ ---      │
# │ i64       ┆ list[str] ┆ list[i64] ┆ list[i64] ┆   ┆ list[i64] ┆ ---       ┆ ---       ┆ i32      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ i32       ┆ i32       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 10000032  ┆ ["MEDS_BI ┆ [0, 2, …  ┆ [0, 52, … ┆ … ┆ []        ┆ 1         ┆ 1         ┆ 0        │
# │           ┆ RTH", "LA ┆ 0]        ┆ 52]       ┆   ┆           ┆           ┆           ┆          │
# ...
